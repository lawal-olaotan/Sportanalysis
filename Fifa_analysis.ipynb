# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

df = pd.read_csv("data.csv")
df.head(11)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2   https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4   https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...

# %%
del df['Photo']
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age Nationality  \
# 0           0  158023           L. Messi   31   Argentina
# 1           1   20801  Cristiano Ronaldo   33    Portugal
# 2           2  190871          Neymar Jr   26      Brazil
# 3           3  193080             De Gea   27       Spain
# 4           4  192985       K. De Bruyne   27     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# ...

# %%
plt.figure(figsize=(15,32))
sns.countplot(y = df.Nationality,palette = 'Set2')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Age",data=df)

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Potential",data=df)

# %%
#Best Goal Keeper

# %%
#assigning variables to get the best goal kepper 
a = 0.5
b = 1
c = 2
d = 3

# %%
#GoalKeeping Characteristics
df['gk_Shot_Stopper'] = (b*df.Reactions + b*df.Composure + a*df.SprintSpeed + a*df.Strength + c*df.Jumping + b*df.GKPositioning + c*df.GKDiving + d*df.GKReflexes + b*df.GKHandling)/(2*a + 4*b + 2*c + 1*d)
df['gk_Sweeper'] = (b*df.Reactions + d*df.Composure + b*df.SprintSpeed + a*df.ShortPassing + a*df.LongPassing + b*df.Jumping + b*df.GKPositioning + b*df.GKDiving + d*df.GKReflexes + b*df.GKHandling + d*df.GKKicking + c*df.Vision)/(2*a + 6*b + 1*c + 2*d)

# %%
plt.figure(figsize = (15,6))
#Generate Sequential data and plot
sd = df.sort_values('gk_Shot_Stopper',ascending= False)[:5]
x1 = np.array(list(sd['Name']))
y1 = np.array(list(sd['gk_Shot_Stopper']))
sns.barplot(x1,y1,palette = "colorblind")
plt.ylabel("Shot Stopping Rank")
# Out:
# Text(0, 0.5, 'Shot Stopping Rank')

# %%
plt.figure(figsize = (15,6))
sd = df.sort_values ('gk_Sweeper',ascending = False)[:5]
x2 = np.array(list(sd['Name']))
y2 = np.array(list(sd['gk_Sweeper']))
sns.barplot(x2,y2,palette = "colorblind")
plt.ylabel("Sweeping Score")
# Out:
# Text(0, 0.5, 'Sweeping Score')

# %%
df['best_keeper'] = (df.gk_Shot_Stopper + df.gk_Sweeper)/(2)

# %%
plt.figure(figsize = (15,6))
sd = df.sort_values('best_keeper',ascending = False)[:5]
x3 = np.array(list(sd['Name']))
y3 = np.array(list(sd['best_keeper']))
sns.barplot(x3,y3,palette = "colorblind")
plt.ylabel("FIFA 2020 BEST KEEPER RANK")
# Out:
# Text(0, 0.5, 'FIFA 2020 BEST KEEPER RANK')

# %%
#lEFT CENTERAL DEFENDER
#attributes 
df['df_centre_backs'] = (d*df.Reactions + c*df.Interceptions + d*df.SlidingTackle + d*df.StandingTackle + b*df.Vision + b*df.Composure + b*df.Crossing + a*df.ShortPassing+ b*df.LongPassing + c*df.Acceleration + b*df.SprintSpeed + d*df.Stamina + d*df.Jumping + d*df.HeadingAccuracy + b*df.LongShots + d*df.Marking + c*df.Aggression)/(6*b + 3*c + 7*d)
df ['df_wingers'] = (b*df.BallControl + a*df.Dribbling + a*df.Marking + d*df.SlidingTackle + d*df.StandingTackle + a*df.Positioning + c*df.Vision + c*df.Crossing + b*df.ShortPassing + c*df.LongPassing + d*df.Acceleration + d*df.SprintSpeed + c*df.Stamina + a*df.Finishing)/(4*a + 2*b + 4*c + 4*d)

# %%
plt.figure(figsize=(15,6))

sd = df[(df['Position']== 'LCB') & (df['Preferred Foot'] == 'Left')].sort_values('df_centre_backs', ascending=False)[:5]
x4 = np.array(list(sd['Name']))
y4 = np.array(list(sd['df_centre_backs']))
sns.barplot(x4,y4,palette = sns.color_palette("Blues_r"))
plt.ylabel("LCB SCORE")
# Out:
# Text(0, 0.5, 'LCB SCORE')

# %%
plt.figure(figsize=(15,6))
sd = df[(df['Position']== 'RCB') & (df['Preferred Foot']== 'Right')].sort_values('df_centre_backs', ascending=False)[:5]
x5 = np.array(list(sd['Name']))
y5 = np.array(list(sd['df_centre_backs']))
sns.barplot(x5,y5,palette = sns.color_palette("Blues_r"))
plt.ylabel("RCB SCORE")
# Out:
# Text(0, 0.5, 'RCB SCORE')

# %%
plt.figure(figsize=(15,6))
sd = df[(df['Position'] == 'LWB') | (df ['Position'] == 'LB')].sort_values('df_wingers',ascending = False)[:5]
x6 = np.array(list(sd['Name'])) 
y6 = np.array(list(sd['df_wingers']))
sns.barplot(x6,y6,palette = sns.color_palette("Blues_r"))
plt.ylabel("Left Back Score")
# Out:
# Text(0, 0.5, 'Left Back Score')

# %%
plt.figure(figsize=(15,6))
sd = df[(df['Position'] == 'RWB') | (df ['Position'] == 'RB')].sort_values('df_wingers',ascending = False)[:5]
x7 = np.array(list(sd['Name'])) 
y7 = np.array(list(sd['df_wingers']))
sns.barplot(x7,y7,palette = sns.color_palette("Blues_r"))
plt.ylabel("Right Back Score")
# Out:
# Text(0, 0.5, 'Right Back Score')

# %%
#PLAYMAKER 
df ['mf_playmaker'] = (d*df.BallControl + d*df.Dribbling + a*df.Marking + d*df.Reactions + d*df.Vision + c*df.Positioning + c*df.Crossing + d*df.ShortPassing + c*df.LongPassing + c*df.Curve + b*df.LongShots + c*df.FKAccuracy)/(1*a + 1*b +4*c+5*d)
df ['mf_beast'] = (d*df.Agility + c*df.Balance + b*df.Jumping + c*df.Strength + d*df.Stamina + a*df.SprintSpeed + c*df.Acceleration + d*df.ShortPassing + c*df.Aggression + d*df.Reactions + b*df.Marking + b*df.StandingTackle + b*df.SlidingTackle + b*df.Interceptions )/(1*a + 5*b + 4*c + 4*d)
df ['mf_controller'] = (d*df.BallControl + a*df.Dribbling + a*df.Marking + a*df.Reactions + c*df.Vision + c*df.Composure + d*df.ShortPassing + d*df.LongPassing) / (2*c + 3*d + 4*a)

# %%
plt.figure(figsize = (15,6))
ss = df[(df['Position']== 'CAM') | (df['Position'] == 'LAM') | (df['Position'] == 'RAM')].sort_values ('mf_playmaker',ascending=False)[:5]
x8 = np.array(list(ss['Name']))
y8 = np.array(list(ss['mf_playmaker']))
sns.barplot(x8,y8,palette = sns.diverging_palette (145,280,s=85,l=25,n=5))
plt.ylabel("PlayMaker Score")
# Out:
# Text(0, 0.5, 'PlayMaker Score')

# %%
plt.figure(figsize=(15,6))

ss = df[(df['Position'] == 'LCM') | (df['Position'] == 'LM')].sort_values('mf_beast',ascending = False)[:5]
x9 = np.array(list(ss['Name']))
y9= np.array(list(ss['mf_beast']))
sns.barplot(x9, y9, palette=sns.diverging_palette(145, 280, s=85, l=25, n=5))
plt.ylabel("Beast Score")
plt.xlabel('Players Name')
# Out:
# Text(0.5, 0, 'Players Name')

# %%
plt.figure(figsize=(15,6))
sy = df[ (df['Position'] == 'RM')].sort_values('mf_controller',ascending = False)[:5]
x10 = np.array(list(sy['Name']))
y10= np.array(list(sy['mf_controller']))
sns.barplot(x10, y10, palette=sns.diverging_palette(145, 280, s=85, l=25, n=5))
plt.ylabel("Beast Score")
plt.xlabel('Players Name')
# Out:
# Text(0.5, 0, 'Players Name')

# %%
df['att_left_wing'] = (c*df.BallControl + c*df.Dribbling + c*df.SprintSpeed + d*df.Acceleration + b*df.Vision + c*df.Crossing + b*df.ShortPassing + b*df.LongPassing + b*df.Aggression + b*df.Agility + a*df.Curve + c*df.LongShots + b*df.FKAccuracy + d*df.Finishing)/(a + 6*b + 5*c + 2*d)
df['att_right_wing'] = (c*df.BallControl + c*df.Dribbling + c*df.SprintSpeed + d*df.Acceleration + b*df.Vision + c*df.Crossing + b*df.ShortPassing + b*df.LongPassing + b*df.Aggression + b*df.Agility + a*df.Curve + c*df.LongShots + b*df.FKAccuracy + d*df.Finishing)/ (a + 6*b + 5*c + 2*d)
df['att_striker'] = (b*df.BallControl + a*df.Vision + b*df.Aggression + b*df.Agility + a*df.Curve + a*df.LongShots + d*df.Balance + d*df.Finishing + d*df.HeadingAccuracy + c*df.Jumping + c*df.Dribbling)/(3*a + 2*b + 2*c + 3*d)

# %%
plt.figure(figsize=(15,6))

so = df[(df['Position']== 'LW')| (df['Position']== 'LM') | (df['Position']=='LS')].sort_values('att_left_wing',ascending = False)[:5]
x10 = np.array(list(so['Name']))
y10 = np.array(list(so['att_left_wing']))
sns.barplot(x10,y10,palette = sns.diverging_palette(235,133,l=60,n=5,center="dark"))
plt.ylabel("Left Wing")
# Out:
# Text(0, 0.5, 'Left Wing')

# %%
plt.figure(figsize=(15,6))

so = df[(df['Position']== 'RW')| (df['Position']== 'RM') | (df['Position']=='RS')].sort_values('att_right_wing',ascending = False)[:5]
x11 = np.array(list(so['Name']))
y11 = np.array(list(so['att_right_wing']))
sns.barplot(x11,y11,palette = sns.diverging_palette(235,133,l=60,n=5,center="dark"))
plt.ylabel("Right Wing")
# Out:
# Text(0, 0.5, 'Right Wing')

# %%
plt.figure(figsize=(15,6))

so = df[(df['Position']== 'ST')| (df['Position']== 'LS') | (df['Position']=='RS')].sort_values('att_striker',ascending = False)[:5]
x11 = np.array(list(so['Name']))
y11 = np.array(list(so['att_striker']))
sns.barplot(x11,y11,palette = sns.diverging_palette(235,133,l=60,n=5,center="dark"))
plt.ylabel("Striker")
# Out:
# Text(0, 0.5, 'Striker')
